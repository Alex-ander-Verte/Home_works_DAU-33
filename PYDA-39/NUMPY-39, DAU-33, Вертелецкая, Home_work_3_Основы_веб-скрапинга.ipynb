# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга"
#
#
# ### Обязательная часть
#
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# > <дата> - <заголовок> - <ссылка на материал>
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
#подключаем библиотеки
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
import re

# %%
# Vers.01 -- date, title, link
def get_habr_posts(query):
    habr_blog = pd.DataFrame()
    for q in query:
        URL = 'https://habr.com/ru/search/'
        params = {
            'q': q
        }
        req = requests.get(URL, params=params)
        time.sleep(0.3)
        soup = BeautifulSoup(req.text)
        articles = soup.find_all('article', class_='tm-articles-list__item')
        for article in articles:
            if article.find(class_="tm-article-snippet__title-link") is None:
                title = article.find(class_="tm-megapost-snippet__link tm-megapost-snippet__card").text
                link = 'https://habr.com' + article.find("a", class_="tm-megapost-snippet__link tm-megapost-snippet__card").get("href")
                date = article.find('time', class_='tm-megapost-snippet__datetime-published').text.strip()
            else:
                title = article.find('h2', class_='tm-article-snippet__title').text
                link = 'https://habr.com' + article.find('h2', class_='tm-article-snippet__title').find('a').get('href')
                date = article.find('span', class_='tm-article-snippet__datetime-published').text.strip()
            row = {'date': date, 'title': title, 'link': link}
            habr_blog = pd.concat([habr_blog, pd.DataFrame([row])]) 
    return habr_blog.reset_index(drop=True)

res = get_habr_posts(['python', 'анализ данных'])
res.drop_duplicates(subset='link')
res
# Out:
#                           date  \
# 0     20  января  2022 в 18:37
# 1    13  декабря  2021 в 09:00
# 2     21  апреля  2020 в 18:35
# 3        6  июля  2021 в 13:29
# 4     13  января  2022 в 18:35
# 5     4  декабря  2020 в 21:03
# 6       8  марта  2022 в 12:13
# 7       3  марта  2020 в 13:22
# 8     16  ноября  2021 в 16:09
# 9    26  декабря  2022 в 14:24
# 10   19  августа  2022 в 18:07
# 11       3  июня  2020 в 09:00
# 12    13  ноября  2020 в 10:10
# 13   25  октября  2022 в 12:02
# 14   31  октября  2019 в 10:02
# 15    6  октября  2021 в 12:36
# 16   11  октября  2021 в 10:02
# 17       3  июня  2022 в 14:47
# 18   24  августа  2022 в 13:07
# 19    5  декабря  2022 в 18:25
# 20      25  июля  2012 в 13:29
# 21      25  июля  2017 в 13:47
# 22   10  августа  2022 в 15:52
# 23    14  января  2021 в 10:00
# 24    21  января  2019 в 11:21
# 25       14  мая  2020 в 13:39
# 26    16  апреля  2020 в 07:10
# 27    13  ноября  2021 в 19:15
# 28   10  декабря  2021 в 13:15
# 29      30  июня  2014 в 23:06
# 30   18  октября  2021 в 15:08
# 31      18  июня  2014 в 15:19
# 32   13  октября  2014 в 14:00
# 33      27  июня  2017 в 13:51
# 34      28  июля  2014 в 13:10
# 35   11  августа  2014 в 10:47
# 36  14  сентября  2014 в 19:54
# 37    23  ноября  2014 в 16:49
# 38           25  декабря  2017
# 39    5  октября  2014 в 19:57
#
#                                                 title  \
# 0   Курс «Python для инженеров». Старт 3 потока 31...
# 1   Жаждущим автоматизации: открытый урок «ChatOps...
# 2   Вышел Python 2.7.18, последний релиз ветки Pyt...
# 3   Python Community Meetup 8/07: видео и материал...
# 4   Открытый урок «Пишем Custom Prometheus Exporte...
# 5   Python как компилируемый статически типизирова...
# 6   Вышел мартовский релиз расширения Python для V...
# 7   В начале этого года Python сместил Java и стал...
# 8   EPAM разработала бесплатный курс по программир...
# 9   Positive Technologies открыла доступ по запрос...
# 10  Осталась неделя до старта 4 потока Python для ...
# 11  Вышла версия 0.0.2 snakeware — дистрибутива Li...
# 12  Создатель Python Гвидо ван Россум выходит на р...
# 13                                  Вышел Python 3.11
# 14  Создатель Python Гвидо ван Россум ушел из Drop...
# 15          Вышел язык программирования Python 3.10.0
# 16  Python вышел на первое место рейтинга TIOBE, и...
# 17  «Тестирование веб-приложений на Python» — новы...
# 18  Python, SQL, С и Java стали самыми популярными...
# 19               Python или Golang: что учить в 2023?
# 20                      Пять лет Школе анализа данных
# 21                10 лет Школе анализа данных Яндекса
# 22  Как за две недели проверить гипотезы применимо...
# 23  Что такое бессерверный SQL? И как использовать...
# 24  Как мы строим систему обработки, хранения и ан...
# 25  Ubic создаст платформу для анализа данных о мо...
# 26  Microsoft анонсировала запуск «Планетарного ко...
# 27  Владимир Путин выступил с Германом Грефом на к...
# 28  Интенсив для повышения квалификации: как испол...
# 29  Обзор наиболее интересных материалов по анализ...
# 30  AI Journey Contest 2021: какие задачи мы подго...
# 31  Обзор наиболее интересных материалов по анализ...
# 32  Обзор наиболее интересных материалов по анализ...
# 33  Использование Python и Excel для обработки и а...
# 34  Обзор наиболее интересных материалов по анализ...
# 35  Обзор наиболее интересных материалов по анализ...
# 36  Обзор наиболее интересных материалов по анализ...
# 37  Обзор наиболее интересных материалов по анализ...
# 38  Новый подход к спортивному анализу данных: как...
# 39  Обзор наиболее интересных материалов по анализ...
#
#                                                  link
# 0   https://habr.com/ru/company/southbridge/news/t...
# 1   https://habr.com/ru/company/southbridge/news/t...
# 2                  https://habr.com/ru/news/t/498364/
# 3   https://habr.com/ru/company/raiffeisenbank/new...
# 4   https://habr.com/ru/company/southbridge/news/t...
# 5                  https://habr.com/ru/news/t/531402/
# 6                  https://habr.com/ru/news/t/654707/
# 7   https://habr.com/ru/company/itsumma/news/t/490...
# 8   https://habr.com/ru/company/epam_systems/news/...
# 9                  https://habr.com/ru/news/t/707698/
# 10  https://habr.com/ru/company/southbridge/news/t...
# 11                 https://habr.com/ru/news/t/505096/
# 12                 https://habr.com/ru/news/t/527858/
# 13                 https://habr.com/ru/news/t/695298/
# 14                 https://habr.com/ru/news/t/473926/
# 15                 https://habr.com/ru/news/t/581862/
# 16                 https://habr.com/ru/news/t/582682/
# 17  https://habr.com/ru/company/yandex_praktikum/n...
# 18                 https://habr.com/ru/news/t/684376/
# 19  https://habr.com/ru/company/southbridge/news/t...
# 20    https://habr.com/ru/company/yandex/blog/148443/
# 21    https://habr.com/ru/company/yandex/blog/334066/
# 22  https://habr.com/ru/company/factory5/blog/681846/
# 23  https://habr.com/ru/company/microsoft/blog/537...
# 24  https://habr.com/ru/company/sibur_official/blo...
# 25                 https://habr.com/ru/news/t/501944/
# 26                 https://habr.com/ru/news/t/497474/
# 27                 https://habr.com/ru/news/t/588991/
# 28  https://habr.com/ru/company/netologyru/news/t/...
# 29                   https://habr.com/ru/post/228187/
# 30  https://habr.com/ru/company/sbercloud/news/t/5...
# 31                   https://habr.com/ru/post/226641/
# 32                   https://habr.com/ru/post/240139/
# 33      https://habr.com/ru/company/otus/blog/331746/
# 34                   https://habr.com/ru/post/231323/
# 35                   https://habr.com/ru/post/232879/
# 36                   https://habr.com/ru/post/236757/
# 37                   https://habr.com/ru/post/243967/
# 38                https://habr.com/ru/article/344806/
# 39                   https://habr.com/ru/post/239247/

# %% [markdown]
# ### Дополнительная часть (необязательная)
#
# Функция из обязательной части задания должна быть расширена следующим образом:
#
# * кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить материалы с первых 4 страниц результатов;
# * в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
#
# > <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>

# %%
# Функция для замены нескольких значений
def multiple_replace(target_str, replace_values):
    # получаем заменяемое: подставляемое из словаря в цикле
    for i, j in replace_values.items():
        # меняем все target_str на подставляемое
        target_str = target_str.replace(i, j)
    return target_str

# создаем словарь со значениями и строку, которую будет изменять
replace_values = {'\n': ' ', '\r' : ' '}

# %%
# Функция для добавления полного текста статьи
def add_full_text(posts_df):
    i = 0
    for el in posts_df['link']:
        req = requests.get(el).text
        soup = BeautifulSoup(req)
        time.sleep(0.3)
        post_text = soup.find('div', class_=['article-formatted-body article-formatted-body article-formatted-body_version-1', 'article-formatted-body article-formatted-body article-formatted-body_version-2']).text.strip()
        post_text = multiple_replace(post_text, replace_values)
        posts_df.loc[i, 'text'] = post_text
        i += 1
    return posts_df

# %%
# Vers.02 -- add full_text, likes and page NEW
def get_habr_posts_full(page, query):
    habr_blog = pd.DataFrame()
    for q in query:
        URL = 'https://habr.com/ru/search/page' + str(page) + '/'
        params = {
            'q': q
        }
        req = requests.get(URL, params=params)
        time.sleep(0.3)
        soup = BeautifulSoup(req.text)
        articles = soup.find_all('article', class_='tm-articles-list__item')
        for article in articles:
            regex = r'Всего голосов.*?(\d+)'
            if article.find(class_="tm-article-snippet__title-link") is None:
                title = article.find(class_="tm-megapost-snippet__link tm-megapost-snippet__card").text
                link = 'https://habr.com' + article.find("a", class_="tm-megapost-snippet__link tm-megapost-snippet__card").get("href")
                date = article.find('time', class_='tm-megapost-snippet__datetime-published').text.strip()
                span_likes = article.find_all('span', class_=['tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating', 
                                                              'tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_appearance-article tm-votes-meter__value_rating'])
            else:
                title = article.find('h2', class_='tm-article-snippet__title').text
                link = 'https://habr.com' + article.find('h2', class_='tm-article-snippet__title').find('a').get('href')
                date = article.find('span', class_='tm-article-snippet__datetime-published').text.strip()
                span_likes = article.find_all('span', class_=['tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating', 
                                                              'tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_appearance-article tm-votes-meter__value_rating'])
            likes = re.findall(regex, str(span_likes))
            likes = int(likes[0])
            row = {'date': date, 'title': title, 'link': link, 'likes': likes}
            habr_blog = pd.concat([habr_blog, pd.DataFrame([row])]) 

    return add_full_text(habr_blog.reset_index(drop=True))
     
res_full = get_habr_posts_full(2, ['python', 'анализ данных'])
res_full.drop_duplicates(subset='link')
res_full
# Out:
#                           date  \
# 0    14  декабря  2022 в 18:01
# 1   16  сентября  2020 в 16:48
# 2     15  января  2022 в 19:00
# 3        18  мая  2022 в 18:33
# 4      18  марта  2022 в 18:31
# 5     22  апреля  2022 в 14:42
# 6     3  августа  2022 в 15:23
# 7   29  сентября  2022 в 09:34
# 8   27  сентября  2021 в 09:03
# 9    10  декабря  2021 в 13:15
# 10    4  февраля  2022 в 14:04
# 11       24  мая  2022 в 10:57
# 12   11  октября  2022 в 09:27
# 13  22  сентября  2021 в 08:03
# 14   18  октября  2021 в 10:08
# 15   20  октября  2021 в 16:43
# 16      27  июня  2022 в 16:57
# 17  19  сентября  2022 в 12:33
# 18     8  ноября  2022 в 13:36
# 19    8  декабря  2021 в 23:20
# 20    18  января  2015 в 18:02
# 21     13  марта  2019 в 16:00
# 22    1  февраля  2015 в 15:55
# 23      30  июня  2017 в 10:52
# 24     7  апреля  2020 в 10:20
# 25       9  июня  2022 в 21:30
# 26    2  октября  2017 в 10:56
# 27     4  ноября  2015 в 23:45
# 28      14  июня  2016 в 12:51
# 29   25  февраля  2020 в 09:17
# 30    16  ноября  2020 в 17:10
# 31       27  мая  2013 в 11:12
# 32   24  августа  2018 в 17:08
# 33  22  сентября  2020 в 16:43
# 34   21  декабря  2013 в 14:55
# 35   14  декабря  2016 в 13:25
# 36    7  октября  2013 в 14:12
# 37   20  октября  2015 в 17:30
# 38   6  сентября  2019 в 13:52
# 39      6  марта  2020 в 02:22
#
#                                                 title  \
# 0                Юбилейный поток Python для инженеров
# 1   Астрономам порекомендовали меньше использовать...
# 2   Разработчик предложил устроить коммунистическу...
# 3   Слёрм запускает 3-дневный интенсив по Python д...
# 4   24 марта Слёрм проведёт открытый урок «Первый ...
# 5   TechnoMeetsPython. Онлайн митап о Python-разра...
# 6    Последний поток Python для инженеров в этом году
# 7   Асинхронное программирование на Python для джу...
# 8   «Разработчикам вход запрещен» или курс «Python...
# 9   Интенсив для повышения квалификации: как испол...
# 10  В Visual Studio Code добавили новые возможност...
# 11  Дайджест Слёрма: тест на уровень кунг-фу по Py...
# 12  Прокачаться в асинхронном программировании на ...
# 13            Открытый вебинар «The Python Packaging»
# 14  Intel оптимизировала библиотеку Numpy под AVX-...
# 15  Новый хакатон от СберЗвука для Python-разработ...
# 16  В стороннем официальном репозитории Python был...
# 17  Асинхронное программирование на Python для джу...
# 18      Показываем полезное с Python meetup от Evrone
# 19  Открытый семинар: FastAPI, или как быстро доба...
# 20  Обзор наиболее интересных материалов по анализ...
# 21       Хакатон по анализу данных в Нижнем Новгороде
# 22  Обзор наиболее интересных материалов по анализ...
# 23  Использование Python и Excel для обработки и а...
# 24  Новые модели поиска и анализа данных. WSDM 202...
# 25  Шаблон новичка на пути PANDAS в искусстве анал...
# 26  3 кейса применения анализа данных в сфере недв...
# 27  Конкурс kaggle по анализу данных анкетирования...
# 28  GoTo АД. Летние школы по программированию, ана...
# 29  Intel NUC для управления и анализа данных с SD...
# 30  Sibur Challenge 2020 — онлайн-чемпионат по ана...
# 31  Оптимизация общественного транспорта после ана...
# 32  Как привлечь специалиста по анализу данных, ко...
# 33  Напишем и поймем Decision Tree на Python с нул...
# 34  Знания о языке и Яндекс. Зачем нам падежи? Лек...
# 35  Как хорошо подать результаты качественного исс...
# 36   Введение в анализ сложности алгоритмов (часть 1)
# 37             Совмещенный АВС и XYZ анализ в Ритейле
# 38  Как превратить трафик в продажи с помощью данн...
# 39           Разбор: что такое фундаментальный анализ
#
#                                                  link  likes  \
# 0   https://habr.com/ru/company/southbridge/news/t...      9
# 1                  https://habr.com/ru/news/t/519414/     26
# 2                  https://habr.com/ru/news/t/645777/     27
# 3   https://habr.com/ru/company/southbridge/news/t...      7
# 4   https://habr.com/ru/company/southbridge/news/t...     20
# 5                  https://habr.com/ru/news/t/662437/      2
# 6   https://habr.com/ru/company/southbridge/news/t...      8
# 7   https://habr.com/ru/company/southbridge/news/t...     15
# 8   https://habr.com/ru/company/southbridge/news/t...     13
# 9   https://habr.com/ru/company/netologyru/news/t/...      6
# 10                 https://habr.com/ru/news/t/649717/     11
# 11  https://habr.com/ru/company/southbridge/news/t...     11
# 12  https://habr.com/ru/company/southbridge/news/t...     11
# 13                 https://habr.com/ru/news/t/579264/      3
# 14  https://habr.com/ru/company/itsumma/news/t/584...     39
# 15                 https://habr.com/ru/news/t/584584/      5
# 16                 https://habr.com/ru/news/t/673668/      9
# 17     https://habr.com/ru/company/kts/news/t/688988/      9
# 18  https://habr.com/ru/company/evrone/news/t/698054/      4
# 19                 https://habr.com/ru/news/t/594325/      4
# 20                   https://habr.com/ru/post/248165/     17
# 21  https://habr.com/ru/company/microsoft/blog/443...     14
# 22                   https://habr.com/ru/post/249415/     18
# 23      https://habr.com/ru/company/otus/blog/331998/     17
# 24    https://habr.com/ru/company/yandex/blog/496004/     21
# 25                   https://habr.com/ru/post/670668/     11
# 26  https://habr.com/ru/company/newprolab/blog/339...      7
# 27                   https://habr.com/ru/post/270131/      9
# 28      https://habr.com/ru/company/goto/blog/302334/     21
# 29     https://habr.com/ru/company/intel/blog/486440/     21
# 30  https://habr.com/ru/company/sibur_official/blo...      1
# 31       https://habr.com/ru/company/ibm/blog/181039/     44
# 32                   https://habr.com/ru/post/421177/     28
# 33                   https://habr.com/ru/post/520204/      7
# 34    https://habr.com/ru/company/yandex/blog/206870/     61
# 35                   https://habr.com/ru/post/317544/     12
# 36                   https://habr.com/ru/post/196560/    106
# 37   https://habr.com/ru/company/datawiz/blog/269167/     14
# 38                   https://habr.com/ru/post/466475/     15
# 39  https://habr.com/ru/company/iticapital/blog/49...     10
#
#                                                  text
# 0   16 января весь Слёрм будет праздновать: старту...
# 1   Астрономы из Лейденской обсерватории опубликов...
# 2   14 января 2022 года разработчик jokteur на Git...
# 3   24-26 июня пройдёт онлайн-интенсив для инженер...
# 4   Думаете, написать свою первую программу на Pyt...
# 5   27 апреля в 18:00 собираем питонистов на YouTu...
# 6   29 августа мы запускаем 4 поток курса «Python ...
# 7   Как джуну выделиться на фоне таких же новичков...
# 8   Полгода назад мы анонсировали первый поток кур...
# 9   14 декабря в Нетологии пройдёт вебинар, посвящ...
# 10  В блоге Microsoft сообщили о нововведениях пла...
# 11  Сделали для вас подборку свежих статей и выгод...
# 12  Через два дня стартует курс по асинхронному пр...
# 13  23 сентября в 16:30 в рамках цикла открытых те...
# 14  Расположение векторного регистрового файла (жё...
# 15  Привет, Хабр! Если вы хотите проверить свои си...
# 16  В официальном стороннем репозитории Python был...
# 17  Привет!3 октября начинается 3-й поток нашего ф...
# 18  Митап завершился, а значит пора поделиться его...
# 19  9 декабря в 16:30 Виктор Бебнев (Xperience AI)...
# 20  Представляю вашему вниманию очередной выпуск о...
# 21  30-31 марта ребята из СИБУР и AI Community про...
# 22  Представляю вашему вниманию очередной выпуск о...
# 23  Первая часть статьи была опубликована тут.  Ка...
# 24  Международные научные конференции помогают сле...
# 25  Доброго времени суток! Меня зовут Алексей. Сей...
# 26  Публикуем обзор первого дня Data Science Week ...
# 27  На kaggle сейчас проходит конкурс USA Census п...
# 28  Был как-то в лагере в Одессе парнишка-школьник...
# 29  Пост-призер новогоднего NUCо-конкурса Intel. В...
# 30  Привет, Хабр!   Мы уже в третий раз запускаем ...
# 31  Группа исследователей из IBM, используя информ...
# 32  На мой взгляд, данная статья будет интересна т...
# 33  Привет, Хабр! Представляю вашему вниманию пере...
# 34  По разным оценкам сейчас в мире существует от ...
# 35  Большинство статей и выступлений про качествен...
# 36  От переводчика: данный текст даётся с незначит...
# 37  Когда-то давно владелец магазина, он же продав...
# 38  Бизнесу важно не только привлекать новых клиен...
# 39  Фундаментальный анализ (FA) — это метод измере...
