# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга"
#
#
# ### Обязательная часть
#
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# > <дата> - <заголовок> - <ссылка на материал>
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
#подключаем библиотеки
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
import re

# %%
# Vers.01 -- date, title, link
def get_habr_posts(query):
    habr_blog = pd.DataFrame()
    URL = 'https://habr.com/ru/search/'
    params = {
        'q': query
    }
    req = requests.get(URL, params=params)
    time.sleep(0.3)
    soup = BeautifulSoup(req.text)
    articles = soup.find_all('article', class_='tm-articles-list__item')
    for article in articles:
        title = article.find('h2', class_='tm-article-snippet__title').text
        link = 'https://habr.com' + article.find('h2', class_='tm-article-snippet__title').find('a').get('href')
        date = article.find('span', class_='tm-article-snippet__datetime-published').text.strip()
        row = {'date': date, 'title': title, 'link': link}
        habr_blog = pd.concat([habr_blog, pd.DataFrame([row])]) 
    return habr_blog.reset_index(drop=True)

res = get_habr_posts(['python', 'анализ данных'])
res
# Out:
#                           date  \
# 0    10  декабря  2021 в 13:15
# 1       27  июня  2017 в 13:51
# 2       30  июня  2017 в 10:52
# 3            9  июня   в 21:30
# 4         6  мая  2021 в 06:01
# 5   22  сентября  2020 в 16:43
# 6    18  октября  2021 в 15:08
# 7       30  июня  2014 в 23:06
# 8     23  ноября  2014 в 16:49
# 9     18  января  2015 в 18:02
# 10  14  сентября  2014 в 19:54
# 11   11  августа  2014 в 10:47
# 12    1  февраля  2015 в 15:55
# 13      18  июня  2014 в 15:19
# 14      28  июля  2014 в 13:10
# 15    2  октября  2017 в 10:56
# 16   23  октября  2017 в 01:42
# 17          4  марта   в 19:00
# 18      24  июля  2015 в 11:20
# 19   4  сентября  2017 в 10:50
#
#                                                 title  \
# 0   Интенсив для повышения квалификации: как испол...
# 1   Использование Python и Excel для обработки и а...
# 2   Использование Python и Excel для обработки и а...
# 3   Шаблон новичка на пути PANDAS в искусстве анал...
# 4       Python, исследование данных и выборы: часть 3
# 5   Напишем и поймем Decision Tree на Python с нул...
# 6   AI Journey Contest 2021: какие задачи мы подго...
# 7   Обзор наиболее интересных материалов по анализ...
# 8   Обзор наиболее интересных материалов по анализ...
# 9   Обзор наиболее интересных материалов по анализ...
# 10  Обзор наиболее интересных материалов по анализ...
# 11  Обзор наиболее интересных материалов по анализ...
# 12  Обзор наиболее интересных материалов по анализ...
# 13  Обзор наиболее интересных материалов по анализ...
# 14  Обзор наиболее интересных материалов по анализ...
# 15  3 кейса применения анализа данных в сфере недв...
# 16  «4 свадьбы и одни похороны» или линейная регре...
# 17        Основы теории вероятностей с помощью Python
# 18                  R и Python — достойные соперники?
# 19   Анализируя криптовалютные рынки с помощью Python
#
#                                                  link
# 0   https://habr.com/ru/company/netologyru/news/t/...
# 1       https://habr.com/ru/company/otus/blog/331746/
# 2       https://habr.com/ru/company/otus/blog/331998/
# 3                    https://habr.com/ru/post/670668/
# 4                    https://habr.com/ru/post/556042/
# 5                    https://habr.com/ru/post/520204/
# 6   https://habr.com/ru/company/sbercloud/news/t/5...
# 7                    https://habr.com/ru/post/228187/
# 8                    https://habr.com/ru/post/243967/
# 9                    https://habr.com/ru/post/248165/
# 10                   https://habr.com/ru/post/236757/
# 11                   https://habr.com/ru/post/232879/
# 12                   https://habr.com/ru/post/249415/
# 13                   https://habr.com/ru/post/226641/
# 14                   https://habr.com/ru/post/231323/
# 15  https://habr.com/ru/company/newprolab/blog/339...
# 16                   https://habr.com/ru/post/340698/
# 17                   https://habr.com/ru/post/654407/
# 18     https://habr.com/ru/company/piter/blog/263457/
# 19     https://habr.com/ru/company/wirex/blog/406363/

# %% [markdown]
# ### Дополнительная часть (необязательная)
#
# Функция из обязательной части задания должна быть расширена следующим образом:
#
# * кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента 4 необходимо получить материалы с первых 4 страниц результатов;
# * в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
#
# > <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>

# %%
# Функция для замены нескольких значений
def multiple_replace(target_str, replace_values):
    # получаем заменяемое: подставляемое из словаря в цикле
    for i, j in replace_values.items():
        # меняем все target_str на подставляемое
        target_str = target_str.replace(i, j)
    return target_str

# создаем словарь со значениями и строку, которую будет изменять
replace_values = {'\n': ' ', '\r' : ' '}

# %%
# Функция для добавления полного текста статьи
def add_full_text(posts_df):
    i = 0
    for el in posts_df['link']:
        req = requests.get(el).text
        soup = BeautifulSoup(req)
        time.sleep(0.3)
        post_text = soup.find('div', class_=['article-formatted-body article-formatted-body article-formatted-body_version-1', 'article-formatted-body article-formatted-body article-formatted-body_version-2']).text.strip()
        post_text = multiple_replace(post_text, replace_values)
        posts_df.loc[i, 'text'] = post_text
        i += 1
    return posts_df

# %%
# Vers.02 -- add full_text, likes and page
def get_habr_posts_full(page, query):
    habr_blog = pd.DataFrame()
    URL = 'https://habr.com/ru/search/page' + str(page) + '/'
    params = {
        'q': query
    }
    req = requests.get(URL, params=params)
    time.sleep(0.3)
    soup = BeautifulSoup(req.text)
    articles = soup.find_all('article', class_='tm-articles-list__item')
    for article in articles:
        title = article.find('h2', class_='tm-article-snippet__title').text
        link = 'https://habr.com' + article.find('h2', class_='tm-article-snippet__title').find('a').get('href')
        date = article.find('span', class_='tm-article-snippet__datetime-published').text.strip()
        span_likes = article.find_all('span', class_=['tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating', 'tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_appearance-article tm-votes-meter__value_rating'])
        regex = r'Всего голосов.*?(\d+)'
        likes = re.findall(regex, str(span_likes))
        likes = int(likes[0])
        row = {'date': date, 'title': title, 'link': link, 'likes': likes}
        habr_blog = pd.concat([habr_blog, pd.DataFrame([row])]) 
    
    res = habr_blog.reset_index(drop=True)
    return  add_full_text(res)

get_habr_posts_full(2, ['python', 'анализ данных'])
# Out:
#                          date  \
# 0    20  ноября  2013 в 03:02
# 1       12  мая  2020 в 09:12
# 2   8  сентября  2017 в 16:59
# 3   11  октября  2013 в 17:58
# 4     8  апреля  2018 в 16:31
# 5    29  апреля  2020 в 12:39
# 6     7  апреля  2021 в 18:51
# 7    5  августа  2021 в 08:18
# 8   3  сентября  2019 в 10:17
# 9    7  октября  2013 в 14:12
# 10   26  ноября  2015 в 10:41
# 11   30  января  2012 в 15:42
# 12     13  сентября   в 07:01
# 13          7  июня   в 07:38
# 14       20  января   в 18:37
# 15          18  мая   в 18:33
# 16  6  сентября  2017 в 21:17
# 17   22  января  2019 в 17:40
# 18    16  марта  2020 в 10:56
# 19   26  ноября  2019 в 22:33
#
#                                                 title  \
# 0        Профилирование и отладка Python, инструменты
# 1   Повторяем когортный анализ, выполненный в Powe...
# 2   Использование Python для обработки в реальном ...
# 3   Введение в визуализацию данных при анализе с п...
# 4               Анализ данных с использованием Python
# 5   Практическое руководство по разработке бэкенд-...
# 6   Как сделать полнотекстовую поисковую машину на...
# 7   Спектральный анализ временных рядов с помощью ...
# 8           Полезная help-ссылка для работы с данными
# 9    Введение в анализ сложности алгоритмов (часть 1)
# 10  Анализ изменения цен в российских интернет-маг...
# 11              Анализ данных. Приближенные множества
# 12   Что мы используем для анализа Android-приложений
# 13  Визуализируем данные из xml в виде социальной ...
# 14  Курс «Python для инженеров». Старт 3 потока 31...
# 15  Слёрм запускает 3-дневный интенсив по Python д...
# 16  Какой язык программирования выбрать для работы...
# 17  Завершающий курс специализации по Python от Ma...
# 18  Какой язык выбрать для работы с данными — R ил...
# 19    56 проектов на Python с открытым исходным кодом
#
#                                                  link  likes  \
# 0         https://habr.com/ru/company/vk/blog/202832/     72
# 1                    https://habr.com/ru/post/501492/      5
# 2                    https://habr.com/ru/post/337494/     15
# 3                    https://habr.com/ru/post/197212/     20
# 4                    https://habr.com/ru/post/353050/     35
# 5     https://habr.com/ru/company/yandex/blog/499534/     70
# 6   https://habr.com/ru/company/skillfactory/blog/...      8
# 7                    https://habr.com/ru/post/571344/      3
# 8         https://habr.com/ru/company/vk/blog/465853/     48
# 9                    https://habr.com/ru/post/196560/    106
# 10                   https://habr.com/ru/post/270895/     33
# 11                   https://habr.com/ru/post/137284/     28
# 12      https://habr.com/ru/company/dsec/blog/685920/     26
# 13                   https://habr.com/ru/post/669980/      4
# 14  https://habr.com/ru/company/southbridge/news/t...     14
# 15  https://habr.com/ru/company/southbridge/news/t...      7
# 16                   https://habr.com/ru/post/337330/     23
# 17        https://habr.com/ru/company/vk/blog/436996/     32
# 18                   https://habr.com/ru/post/475210/     21
# 19    https://habr.com/ru/company/edison/blog/477442/     37
#
#                                                  text
# 0   В предыдущей статье мы на практике разобрались...
# 1   Добрый день уважаемые читатели! Поводом для на...
# 2   Постановка задачи  Цифровые и аналоговые датчи...
# 3   Доброго времени суток, уважаемые читатели.  Ка...
# 4   Язык программирования Python в последнее время...
# 5   Привет, меня зовут Александр Васин, я бэкенд-р...
# 6   Полнотекстовый поиск — неотъемлемая часть наше...
# 7   С развитием информационных технологий професси...
# 8   Хабр, привет. Представляю вам главную help-ссы...
# 9   От переводчика: данный текст даётся с незначит...
# 10  В последние пару лет меня достаточно сильно ин...
# 11  Решил создать серию постов об анализе данных. ...
# 12  Всем привет! В этой статье расскажем про инстр...
# 13  Если у Вас есть данные о связях людей в XML фо...
# 14  Курс нацелен дать максимальную пользу, поэтому...
# 15  24-26 июня пройдёт онлайн-интенсив для инженер...
# 16  У начинающего специалиста по данным (data scie...
# 17  Python — простой и гибкий язык, применяемый во...
# 18  По запросу R или Python в интернете вы найдёте...
# 19  1. Flask  Это микро-фреймворк, написанный на P...
