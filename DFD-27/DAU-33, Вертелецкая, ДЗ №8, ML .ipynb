# %% [markdown]
# # Предсказываем траты на след месяц

# %% [markdown]
# ## Загужаем необходимые библиотеки

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Загружаем данные

# %%
# Загрузите данные из файла .csv в переменную df
df = pd.read_csv('таблица для ДЗ №8, ML - Лист1.csv', sep = ',')

# %%
df.head()
# Out:
#    траты_в_позапрошлом_месяце  траты_в_прошлом_месяце  траты_в_тек_месяце  \
# 0                       500.0                   123.0               694.0
# 1                       350.0                   547.0               267.0
# 2                       869.0                    65.0                11.0
# 3                       157.0                    58.0                59.0
# 4                       659.0                   559.0               973.0
#
#    траты_в_след_месяце
# 0                560.0
# 1                423.0
# 2                100.0
# 3                 89.0
# 4                750.0

# %% [markdown]
# ## Смотрим статистику, что нет пропусков и отсуствующих значений

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   траты_в_позапрошлом_месяце  9 non-null      float64
#  1   траты_в_прошлом_месяце      9 non-null      float64
#  2   траты_в_тек_месяце          9 non-null      float64
#  3   траты_в_след_месяце         9 non-null      float64
# dtypes: float64(4)
# memory usage: 416.0 bytes

# %%
df.describe()
# Out:
#        траты_в_позапрошлом_месяце  траты_в_прошлом_месяце  траты_в_тек_месяце  \
# count                    9.000000                9.000000            9.000000
# mean                  1701.777778             1339.777778         1775.777778
# std                   3553.061278             3350.238715         4059.203148
# min                     50.000000               36.000000           11.000000
# 25%                    348.000000               64.000000          267.000000
# 50%                    500.000000              123.000000          450.000000
# 75%                    869.000000              547.000000          694.000000
# max                  11125.000000            10256.000000        12569.000000
#
#        траты_в_след_месяце
# count             9.000000
# mean           1616.555556
# std            3659.733806
# min              89.000000
# 25%             168.000000
# 50%             540.000000
# 75%             563.000000
# max           11356.000000

# %% [markdown]
# ## Формируем признаки и целевую переменную

# %%
## Сформируйте признаки и целевую переменную

# %%
X = df[['траты_в_позапрошлом_месяце', 'траты_в_прошлом_месяце','траты_в_тек_месяце']] 
y = df[['траты_в_след_месяце']]

# %% [markdown]
# ## Разделяем данные на выборку для обучения/проверки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Создаем и обучаем модель линейной регресии

# %%
# Создайте и обучите модель
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Получаем предсказание и оцениваем качество

# %%
# Получите предсказание

# %%
lr.coef_
# Out:
# array([[0.19677661, 0.26074163, 0.56321351]])

# %%
# Оцените качество, при помощи метода mean_squared_error для тестовой выборки

# %%
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 168631.6063051862

# %%
mean_squared_error(y_train, lr.predict(X_train))
# Out:
# 3357.559099508344
